# %%
# Our business case is to predict customer charges for an insurance company based on given variables. 
# So that the company can decide how much they charge people correctly.


import numpy as np #linear Algebra
import pandas as pd # data manipulation and analysis
import matplotlib.pyplot as plt # data visualisation
import seaborn as sns # data visualisation

sns.set_style('whitegrid') #set style for visualisation

import warnings #ignore warnings
warnings.filterwarnings('ignore')


df = pd.read_csv('/home/titanicdwarf/Documents/Data Analysis projects/Python/Insurance/insurance.csv')  #Accessing data

#Data Understanding
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.sample(5)
# Out:
#      age     sex     bmi  children smoker     region      charges
# 893   47    male  38.940         2    yes  southeast  44202.65360
# 701   50  female  44.745         0     no  northeast   9541.69555
# 821   26    male  17.670         0     no  northwest   2680.94930
# 993   38    male  28.270         1     no  southeast   5484.46730
# 667   40  female  32.775         2    yes  northwest  40003.33225

# %%
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.describe(include='O')
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
list(df.sex.unique())
# Out:
# ['female', 'male']

# %%
list(df.region.unique())
# Out:
# ['southwest', 'southeast', 'northwest', 'northeast']

# %%
#data cleaning
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df[df.duplicated(keep='first')]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df.drop_duplicates(keep='first', inplace=True)

# %%
df[df.duplicated(keep='first')]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, children, smoker, region, charges]
# Index: []

# %%
#Data Visualisation (Univariate Analysis - analysis with one variable)
plt.figure(figsize=(10,6))
sns.distplot(df.charges,color='r')
plt.title('Charges Distrinution', size=18)
plt.xlabel('Charges',size=14)
plt.ylabel('Density',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.displot(df.age, color='g')
plt.title('Age Distribution',size=18)
plt.xlabel('Age',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df.bmi,color= 'y')
plt.title('BMI Distribution',size=18)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df.charges)
plt.title('Distribution Charges', size=18)
plt.show()

# %%
#Removing outliers (IQR Method)
Q1= df['charges'].quantile(0.25)
Q3=df['charges'].quantile(0.75)
IQR=Q3-Q1
print(IQR)
# Out:
# 11899.625365

# %%
#Check the outliers
df[(df['charges']<Q1-1.5*IQR) | (df['charges']>Q3+1.5*IQR)]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# 29     31    male  36.300         2    yes  southwest  38711.00000
# 30     22    male  35.600         0    yes  southwest  35585.57600
# ...   ...     ...     ...       ...    ...        ...          ...
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1301   62    male  30.875         3    yes  northwest  46718.16325
# 1303   43    male  27.800         0    yes  southwest  37829.72420
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1323   42  female  40.370         2    yes  southeast  43896.37630
#
# [139 rows x 7 columns]

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='sex',data =df)
plt.title('Total Number of Male and Female', size=18)
plt.xlabel('Sex',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(df.children)
plt.title('Children Distribution',size=18)
plt.xlabel('Children',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(df.smoker)
plt.title('Smoker Distribution',size=18)
plt.xlabel('Smoker',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
df.smoker.value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(df.region, palette='Blues')
plt.title('Region Distribution',size=18)
plt.xlabel('Region',size=14)
plt.ylabel('Count',size=14)
plt.show()

# %%
#Data Visualisation (Bivariate Analysis)
plt.figure(figsize=(10,6))
sns.scatterplot(x='age',y='charges', color='b',data=df)
plt.title('Age vs Charges',size=18)
plt.xlabel('Age',size=14)
plt.ylabel('Charges',size=14)
plt.show()

# %%
print('Correlation between age and charges is :  {}'.format(round(df.corr()['age']['charges'],3)))
# Out:
# Correlation between age and charges is :  0.299

# %%
plt.figure(figsize=(10,6))
sns.set_style('darkgrid')
sns.boxplot(x='smoker',y='charges', data=df)
plt.title('Smoker vs Charges',size=18)
# Out:
# Text(0.5, 1.0, 'Smoker vs Charges')

# %%
sns.pairplot(df,
                markers="+",
                diag_kind="kde",
                kind="reg",
                plot_kws={'line_kws':{'color':'#aec6cf'},
                          'scatter_kws': {'alpha': 0.7,
                                          'color': 'red'}},
                corner=True);

# %%
#Data Visualisation (Multivariate Analysis - more than 2 variables)
plt.figure(figsize = (10,6))
sns.heatmap(df.corr(),annot=True,square=True,
             cmap='RdBu',
             vmax=1,
             vmin=-1)
plt.title('Correlations Between Variables', size=18)
plt.xticks(size=13)
plt.yticks(size=13)
plt.show()
