# %%
#Labraries

import pandas as pd
import numpy as np
import seaborn as sns
import re

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')


# %matplotlib inline
#Configuration of the plot which will be created
matplotlib.rcParams['figure.figsize']= (12,8) 



# Read dataSet
df =pd.read_csv('/home/titanicdwarf/Documents/Data Analysis projects/Python/Movie/movies.csv')

# %%
#Checking the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
Checking Data Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      7668 non-null   object
#  1   rating    7591 non-null   object
#  2   genre     7668 non-null   object
#  3   year      7668 non-null   int64
#  4   released  7666 non-null   object
#  5   score     7665 non-null   float64
#  6   votes     7665 non-null   float64
#  7   director  7668 non-null   object
#  8   writer    7665 non-null   object
#  9   star      7667 non-null   object
#  10  country   7665 non-null   object
#  11  budget    5497 non-null   float64
#  12  gross     7479 non-null   float64
#  13  company   7651 non-null   object
#  14  runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
#check for missing data
for col in df.columns:
    pct_missing= np.mean(df[col].isnull())
    print('{}- {}%'.format(col, pct_missing))
# Out:
# name- 0.0%
# rating- 0.010041731872717789%
# genre- 0.0%
# year- 0.0%
# released- 0.0002608242044861763%
# score- 0.0003912363067292645%
# votes- 0.0003912363067292645%
# director- 0.0%
# writer- 0.0003912363067292645%
# star- 0.00013041210224308815%
# country- 0.0003912363067292645%
# budget- 0.2831246739697444%
# gross- 0.02464788732394366%
# company- 0.002217005738132499%
# runtime- 0.0005216484089723526%

# %%
#Count the null values
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
#List the null values on the data-frame per column
df[df['runtime'].isnull()]
# Out:
#                         name rating   genre  year  \
# 5728  Saw: The Final Chapter      R   Crime  2010
# 5730             The Wolfman      R   Drama  2010
# 6195       One for the Money  PG-13  Action  2012
# 7665           Saving Mbango    NaN   Drama  2020
#
#                               released  score     votes             director  \
# 5728                               NaN    5.6   93000.0       Kevin Greutert
# 5730                               NaN    5.8  104000.0         Joe Johnston
# 6195  January 27, 2012 (United States)    5.3   41000.0  Julie Anne Robinson
# 7665         April 27, 2020 (Cameroon)    5.7      29.0         Nkanya Nkwai
#
#                    writer              star        country      budget  \
# 5728       Patrick Melton        Tobin Bell            NaN         NaN
# 5730  Andrew Kevin Walker  Benicio Del Toro            NaN         NaN
# 6195        Stacy Sherman   Katherine Heigl  United States  40000000.0
# ...

# %%
df[df['company'].isnull()]
# Out:
#                         name   rating      genre  year  \
# 408        A Night in Heaven        R      Drama  1983
# 464               White Star      NaN      Drama  1983
# 469           Last Plane Out       PG     Action  1983
# 633                 The Bear       PG  Biography  1984
# 969             Modern Girls    PG-13     Comedy  1986
# 1033       P.O.W. the Escape        R     Action  1986
# 1572          Heart of Dixie       PG      Drama  1989
# 1594             Lost Angels        R      Drama  1989
# 1630        Staying Together        R     Comedy  1989
# 1806                 Streets        R     Action  1990
# 5728  Saw: The Final Chapter        R      Crime  2010
# 5730             The Wolfman        R      Drama  2010
# 7599      End of the Century  Unrated      Drama  2019
# 7657                    Leap      NaN      Drama  2020
# 7662           The Robinsons      NaN     Action  2020
# 7663            More to Life      NaN      Drama  2020
# ...

# %%
#Couting all of the not null values
df.notnull().sum()
# Out:
# name        7668
# rating      7591
# genre       7668
# year        7668
# released    7666
# score       7665
# votes       7665
# director    7668
# writer      7665
# star        7667
# country     7665
# budget      5497
# gross       7479
# company     7651
# runtime     7664
# dtype: int64

# %%
df.shape
# Out:
# (7668, 15)

# %%
#Remove the columns with null values, since I will not be able to fill in the missing data
df.dropna(how='any').shape
# Out:
# (5421, 15)

# %%
#Assigning the new data-frame
df = df.dropna(how='any')

# %%
#Checking for any null values left in the columns
df.isnull().sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
# Chenging data type of columns Gross and Budget
df.astype({'budget': 'int64'})
df.astype({'gross':'int64'}).dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df.head(10)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
# 5                                 Friday the 13th      R     Horror  1980
# 6                              The Blues Brothers      R     Action  1980
# 7                                     Raging Bull      R  Biography  1980
# 8                                     Superman II     PG     Action  1980
# 9                                 The Long Riders      R  Biography  1980
#
#                             released  score      votes            director  \
# 0      June 13, 1980 (United States)    8.4   927000.0     Stanley Kubrick
# ...

# %%
#Fix the realease Dates
df.astype({'released':'str'}).dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
# Remove the name of the country fom the "release" Column
df['released']= df['released'].str.replace(r"\(.*?\)","")
# Out:
# /tmp/ipykernel_254668/2713138327.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['released']= df['released'].str.replace(r"\(.*?\)","")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#          released  score      votes         director                   writer  \
# 0  June 13, 1980     8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980     5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980     8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980     7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980     7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
df['released'].head(10)
# Out:
# 0        June 13, 1980
# 1         July 2, 1980
# 2        June 20, 1980
# 3         July 2, 1980
# 4        July 25, 1980
# 5          May 9, 1980
# 6        June 20, 1980
# 7    December 19, 1980
# 8        June 19, 1981
# 9         May 16, 1980
# Name: released, dtype: object

# %%
#Remove the year from the 'Release' Row
df['released'].str.split(',').str[1]
# Out:
# 0        1980
# 1        1980
# 2        1980
# 3        1980
# 4        1980
#          ...
# 7663     2020
# 7664     2020
# 7665     2020
# 7666     2020
# 7667     2020
# Name: released, Length: 7668, dtype: object

# %%
df['YearCorrect']= df['released'].str.split(',').str[1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         7668 non-null   object
#  1   rating       7591 non-null   object
#  2   genre        7668 non-null   object
#  3   year         7668 non-null   int64
#  4   released     7666 non-null   object
#  5   score        7665 non-null   float64
#  6   votes        7665 non-null   float64
#  7   director     7668 non-null   object
#  8   writer       7665 non-null   object
#  9   star         7667 non-null   object
#  10  country      7665 non-null   object
#  11  budget       5497 non-null   float64
#  12  gross        7479 non-null   float64
#  13  company      7651 non-null   object
#  14  runtime      7664 non-null   float64
#  15  YearCorrect  7609 non-null   object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 958.6+ KB

# %%
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#          released  score      votes         director                   writer  \
# 0  June 13, 1980     8.4   927000.0  Stanley Kubrick             Stephen King
# 1   July 2, 1980     5.8    65000.0   Randal Kleiser  Henry De Vere Stacpoole
# 2  June 20, 1980     8.7  1200000.0   Irvin Kershner           Leigh Brackett
# 3   July 2, 1980     7.7   221000.0     Jim Abrahams             Jim Abrahams
# 4  July 25, 1980     7.3   108000.0     Harold Ramis       Brian Doyle-Murray
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
# ...                                          ...    ...     ...   ...
# 7663                                More to Life    NaN   Drama  2020
# 7664                                 Dream Round    NaN  Comedy  2020
# 7665                               Saving Mbango    NaN   Drama  2020
# 7666                                It's Just Us    NaN   Drama  2020
# 7667                                   Tee em el    NaN  Horror  2020
#
#                 released  score      votes       director              writer  \
# ...

# %%
#Drop duplicates
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#Check for correlation

#Scatter plot with budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earsnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
#Plot the Budget vs Gross
sns.regplot(x='budget',y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
#Correlection heatMap (treeMap)
df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(method='kendall') #person(default), kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)
plt.title('Correlation Matrix for Numeric features')
plt.xlabel('Moovie features')
plt.ylabel('Movie features')
plt.show()

# %%
#Displat the Movies features correlation has a list
corr_pairs = correlation_matrix.unstack()
corr_pairs
# Out:
# year     year       1.000000
#          score      0.097995
#          votes      0.222945
#          budget     0.329321
#          gross      0.257486
#          runtime    0.120811
# score    year       0.097995
#          score      1.000000
#          votes      0.409182
#          budget     0.076254
#          gross      0.186258
#          runtime    0.399451
# votes    year       0.222945
#          score      0.409182
#          votes      1.000000
#          budget     0.442429
#          gross      0.630757
#          runtime    0.309212
# budget   year       0.329321
#          score      0.076254
#          votes      0.442429
#          budget     1.000000
#          gross      0.740395
#          runtime    0.320447
# gross    year       0.257486
#          score      0.186258
#          votes      0.630757
#          budget     0.740395
#          gross      1.000000
#          runtime    0.245216
# runtime  year       0.120811
#          score      0.399451
# ...

# %%
#Sorting the Movie features correlation
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# budget   score      0.076254
# score    budget     0.076254
# year     score      0.097995
# score    year       0.097995
# year     runtime    0.120811
# runtime  year       0.120811
# gross    score      0.186258
# score    gross      0.186258
# year     votes      0.222945
# votes    year       0.222945
# gross    runtime    0.245216
# runtime  gross      0.245216
# year     gross      0.257486
# gross    year       0.257486
# votes    runtime    0.309212
# runtime  votes      0.309212
# budget   runtime    0.320447
# runtime  budget     0.320447
# budget   year       0.329321
# year     budget     0.329321
# score    runtime    0.399451
# runtime  score      0.399451
# score    votes      0.409182
# votes    score      0.409182
#          budget     0.442429
# budget   votes      0.442429
# votes    gross      0.630757
# gross    votes      0.630757
# budget   gross      0.740395
# gross    budget     0.740395
# year     year       1.000000
# budget   budget     1.000000
# ...

# %%
#Display the Movie features with correlation higher than 0.5
high_cor=sorted_pairs[(sorted_pairs)>0.5]
high_corr = high_cor[(high_cor)<1]
high_corr
# Out:
# votes   gross     0.630757
# gross   votes     0.630757
# budget  gross     0.740395
# gross   budget    0.740395
# dtype: float64
